# %%
import os
import pynbody
import numpy as np
def load_amiga_grp(filename):
    # Assuming the file contains an integer halo ID for each particle in a single column
    halo_ids = np.loadtxt(filename, dtype=np.int32)
    return halo_ids

def load_iord(filename):
    # Assuming the file contains a list of particle IDs in a single column
    particle_ids = np.loadtxt(filename, dtype=np.int64)  # Using int64 if IDs are large
    return particle_ids
    

def validate_file_path(file_path):
    """Check if a file exists at the given path and print a message."""
    if os.path.exists(file_path):
        print(f"File found: {file_path}")
        return True
    else:
        print(f"File not found: {file_path}")
        return False



# Simulation paths
s1path = '/data/REPOSITORY/dwarf_volumes/storm.cosmo25cmb.4096/storm.cosmo25cmb.4096.004096'
s2path = '/data/akaxia/storm/storm.cosmo25cmbsi2s50v35.4096/storm.cosmo25cmbsi2s50v35.4096.004096'

# Load the simulations
s_1 = pynbody.load(s1path)
s_2 = pynbody.load(s2path)

# AHF file paths for the substructure files
ahf_basename_s1 = '/data/REPOSITORY/dwarf_volumes/storm.cosmo25cmb.4096/storm.cosmo25cmb.4096.004096.0000.z0.000.AHF_particles'
ahf_basename_s2 = '/data/akaxia/storm/storm.cosmo25cmbsi2s50v35.4096/storm.cosmo25cmbsi2s50v35.4096.004096.z0.000.AHF_particles'

amiga_file = '/data/REPOSITORY/dwarf_volumes/storm.cosmo25cmb.4096/storm.cosmo25cmb.4096.004096.amiga.grp'
iord_file = '/data/akaxia/storm/storm.cosmo25cmbsi2s50v35.4096/storm.cosmo25cmbsi2s50v35.4096.004096.iord'

amiga_halo_ids = load_amiga_grp(amiga_file)
print("Loaded AMIGA halo IDs:", amiga_halo_ids)
print("Total particles:", len(amiga_halo_ids))
print("Example of halo IDs:", amiga_halo_ids[:10])  # Show the first 10 halo IDs

iord_particle_ids = load_iord(iord_file)
print("Loaded IORD particle IDs:", iord_particle_ids)
print("Total particles:", len(iord_particle_ids))
print("Example of particle IDs:", iord_particle_ids[:10]) # Show the first 10 particle IDs

unique_halos, counts = np.unique(amiga_halo_ids, return_counts=True)
print("Number of unique halos:", len(unique_halos))
print("Particles per halo:", counts)
print("Most populous halo ID and count:", unique_halos[np.argmax(counts)], np.max(counts))
# Out:
# Loaded AMIGA halo IDs: [133973400         0         0 ...         0         0         0]
# Total particles: 133973401
# Example of halo IDs: [133973400         0         0         0         0         0         0
#          0         0         0]
# Loaded IORD particle IDs: [133973400         0         1 ... 133973397 133973398 133973399]
# Total particles: 133973401
# Example of particle IDs: [133973400         0         1         2         3         4         5
#          6         7         8]
# Number of unique halos: 23917
# Particles per halo: [75634913 10890459  6154067 ...       64       64        1]
# Most populous halo ID and count: 0 75634913

# %%
def match_halos(amiga_halo_ids, iord_particle_ids):
    # Maps each particle to its halo
    particle_to_halo = {index: halo_id for index, halo_id in enumerate(amiga_halo_ids) if halo_id != 0}

    # Calculate the halo membership from iord particle IDs
    halo_membership = {}
    for particle_id in iord_particle_ids:
        if particle_id in particle_to_halo:
            halo_id = particle_to_halo[particle_id]
            if halo_id in halo_membership:
                halo_membership[halo_id].append(particle_id)
            else:
                halo_membership[halo_id] = [particle_id]

    return halo_membership

# Run the matching function
halo_matches = match_halos(amiga_halo_ids, iord_particle_ids)
for halo_id, members in halo_matches.items():
    print(f"Halo ID {halo_id} has {len(members)} particles from iord file.")
# Out:
# Halo ID 133973400 has 1 particles from iord file.
# Halo ID 9869 has 286 particles from iord file.
# Halo ID 162 has 30462 particles from iord file.
# Halo ID 1358 has 2084 particles from iord file.
# Halo ID 23873 has 98 particles from iord file.
# Halo ID 29761 has 73 particles from iord file.
# Halo ID 31221 has 68 particles from iord file.
# Halo ID 1748 has 1824 particles from iord file.
# Halo ID 7242 has 401 particles from iord file.
# Halo ID 23791 has 98 particles from iord file.
# Halo ID 24484 has 95 particles from iord file.
# Halo ID 18789 has 132 particles from iord file.
# Halo ID 16980 has 149 particles from iord file.
# Halo ID 16500 has 154 particles from iord file.
# Halo ID 6629 has 444 particles from iord file.
# Halo ID 14318 has 183 particles from iord file.
# Halo ID 11279 has 244 particles from iord file.
# Halo ID 906 has 3718 particles from iord file.
# Halo ID 15590 has 165 particles from iord file.
# Halo ID 5799 has 512 particles from iord file.
# Halo ID 22268 has 106 particles from iord file.
# Halo ID 11956 has 228 particles from iord file.
# Halo ID 9838 has 287 particles from iord file.
# Halo ID 135 has 38630 particles from iord file.
# Halo ID 10496 has 266 particles from iord file.
# Halo ID 17519 has 143 particles from iord file.
# Halo ID 1338 has 2410 particles from iord file.
# Halo ID 26 has 323249 particles from iord file.
# Halo ID 16291 has 157 particles from iord file.
# Halo ID 21550 has 111 particles from iord file.
# Halo ID 4884 has 618 particles from iord file.
# Halo ID 13671 has 194 particles from iord file.
# Halo ID 26096 has 87 particles from iord file.
# Halo ID 22541 has 105 particles from iord file.
# Halo ID 25689 has 89 particles from iord file.
# Halo ID 29477 has 74 particles from iord file.
# Halo ID 24015 has 97 particles from iord file.
# Halo ID 8766 has 325 particles from iord file.
# Halo ID 12872 has 209 particles from iord file.
# Halo ID 10355 has 271 particles from iord file.
# Halo ID 8976 has 317 particles from iord file.
# Halo ID 8376 has 342 particles from iord file.
# Halo ID 31193 has 68 particles from iord file.
# Halo ID 26118 has 87 particles from iord file.
# Halo ID 16729 has 152 particles from iord file.
# Halo ID 13334 has 200 particles from iord file.
# Halo ID 8388 has 342 particles from iord file.
# Halo ID 14900 has 174 particles from iord file.
# Halo ID 22549 has 105 particles from iord file.
# Halo ID 12810 has 210 particles from iord file.
# Halo ID 28592 has 77 particles from iord file.
# Halo ID 13559 has 196 particles from iord file.
# Halo ID 15938 has 161 particles from iord file.
# Halo ID 27990 has 80 particles from iord file.
# Halo ID 11118 has 248 particles from iord file.
# Halo ID 11402 has 241 particles from iord file.
# Halo ID 3278 has 930 particles from iord file.
# Halo ID 32853 has 64 particles from iord file.
# Halo ID 29360 has 74 particles from iord file.
# Halo ID 17746 has 141 particles from iord file.
# Halo ID 4553 has 660 particles from iord file.
# Halo ID 5035 has 546 particles from iord file.
# Halo ID 16701 has 152 particles from iord file.
# Halo ID 6974 has 419 particles from iord file.
# Halo ID 15796 has 162 particles from iord file.
# Halo ID 2848 has 1080 particles from iord file.
# Halo ID 21544 has 111 particles from iord file.
# Halo ID 31487 has 67 particles from iord file.
# Halo ID 22906 has 103 particles from iord file.
# Halo ID 19171 has 128 particles from iord file.
# Halo ID 10433 has 268 particles from iord file.
# Halo ID 26743 has 84 particles from iord file.
# Halo ID 17006 has 148 particles from iord file.
# Halo ID 2160 has 1442 particles from iord file.
# Halo ID 377 has 9972 particles from iord file.
# Halo ID 18871 has 131 particles from iord file.
# Halo ID 2915 has 1053 particles from iord file.
# Halo ID 14038 has 188 particles from iord file.
# Halo ID 17116 has 147 particles from iord file.
# Halo ID 4638 has 647 particles from iord file.
# Halo ID 13342 has 200 particles from iord file.
# Halo ID 23120 has 101 particles from iord file.
# Halo ID 9018 has 315 particles from iord file.
# Halo ID 16174 has 158 particles from iord file.
# Halo ID 23992 has 97 particles from iord file.
# Halo ID 27115 has 83 particles from iord file.
# Halo ID 10087 has 279 particles from iord file.
# Halo ID 17890 has 140 particles from iord file.
# Halo ID 15081 has 171 particles from iord file.
# Halo ID 27111 has 83 particles from iord file.
# Halo ID 31266 has 68 particles from iord file.
# Halo ID 18841 has 131 particles from iord file.
# Halo ID 5866 has 506 particles from iord file.
# Halo ID 24710 has 93 particles from iord file.
# Halo ID 22227 has 107 particles from iord file.
# Halo ID 14527 has 180 particles from iord file.
# Halo ID 8486 has 337 particles from iord file.
# Halo ID 20752 has 116 particles from iord file.
# Halo ID 17037 has 148 particles from iord file.
# Halo ID 20241 has 120 particles from iord file.
# Halo ID 31158 has 69 particles from iord file.
# Halo ID 16822 has 151 particles from iord file.
# Halo ID 12865 has 209 particles from iord file.
# Halo ID 3810 has 793 particles from iord file.
# Halo ID 19185 has 128 particles from iord file.
# Halo ID 22291 has 106 particles from iord file.
# Halo ID 26040 has 87 particles from iord file.
# Halo ID 20266 has 120 particles from iord file.
# Halo ID 15259 has 169 particles from iord file.
# Halo ID 25071 has 92 particles from iord file.
# Halo ID 17608 has 142 particles from iord file.
# Halo ID 14370 has 183 particles from iord file.
# Halo ID 13119 has 205 particles from iord file.
# Halo ID 20229 has 120 particles from iord file.
# Halo ID 14685 has 178 particles from iord file.
# Halo ID 7009 has 417 particles from iord file.
# Halo ID 19168 has 128 particles from iord file.
# Halo ID 23709 has 98 particles from iord file.
# Halo ID 20914 has 115 particles from iord file.
# Halo ID 28398 has 78 particles from iord file.
# Halo ID 5138 has 585 particles from iord file.
# Halo ID 909 has 3708 particles from iord file.
# Halo ID 2090 has 1492 particles from iord file.
# Halo ID 5891 has 504 particles from iord file.
# Halo ID 10914 has 254 particles from iord file.
# Halo ID 8872 has 321 particles from iord file.
# Halo ID 2425 has 1267 particles from iord file.
# Halo ID 28930 has 76 particles from iord file.
# Halo ID 21244 has 113 particles from iord file.
# Halo ID 9918 has 284 particles from iord file.
# Halo ID 19587 has 125 particles from iord file.
# Halo ID 22623 has 104 particles from iord file.
# Halo ID 10192 has 275 particles from iord file.
# Halo ID 28490 has 78 particles from iord file.
# Halo ID 12068 has 225 particles from iord file.
# Halo ID 29153 has 75 particles from iord file.
# Halo ID 22711 has 104 particles from iord file.
# Halo ID 21861 has 109 particles from iord file.
# Halo ID 19367 has 127 particles from iord file.
# Halo ID 7797 has 367 particles from iord file.
# Halo ID 21700 has 110 particles from iord file.
# Halo ID 13613 has 195 particles from iord file.
# Halo ID 27091 has 83 particles from iord file.
# Halo ID 28724 has 77 particles from iord file.
# Halo ID 31651 has 67 particles from iord file.
# Halo ID 31069 has 69 particles from iord file.
# Halo ID 26628 has 85 particles from iord file.
# Halo ID 12191 has 223 particles from iord file.
# Halo ID 24439 has 95 particles from iord file.
# Halo ID 25786 has 89 particles from iord file.
# Halo ID 23077 has 102 particles from iord file.
# Halo ID 15980 has 160 particles from iord file.
# Halo ID 904 has 3738 particles from iord file.
# Halo ID 7578 has 382 particles from iord file.
# Halo ID 17509 has 143 particles from iord file.
# Halo ID 525 has 5824 particles from iord file.
# Halo ID 10609 has 263 particles from iord file.
# Halo ID 3784 has 668 particles from iord file.
# Halo ID 20892 has 115 particles from iord file.
# Halo ID 27574 has 81 particles from iord file.
# Halo ID 1266 has 2547 particles from iord file.
# Halo ID 16413 has 155 particles from iord file.
# Halo ID 18510 has 134 particles from iord file.
# Halo ID 26805 has 84 particles from iord file.
# Halo ID 14238 has 185 particles from iord file.
# Halo ID 14630 has 179 particles from iord file.
# Halo ID 25352 has 90 particles from iord file.
# Halo ID 21044 has 114 particles from iord file.
# Halo ID 20494 has 118 particles from iord file.
# Halo ID 30863 has 69 particles from iord file.
# Halo ID 28830 has 76 particles from iord file.
# Halo ID 12829 has 210 particles from iord file.
# Halo ID 27896 has 80 particles from iord file.
# Halo ID 19949 has 122 particles from iord file.
# Halo ID 31230 has 68 particles from iord file.
# Halo ID 29668 has 73 particles from iord file.
# Halo ID 11635 has 235 particles from iord file.
# Halo ID 5063 has 595 particles from iord file.
# Halo ID 9132 has 311 particles from iord file.
# Halo ID 4945 has 609 particles from iord file.
# Halo ID 16131 has 158 particles from iord file.
# Halo ID 24456 has 95 particles from iord file.
# Halo ID 2921 has 1052 particles from iord file.
# Halo ID 29480 has 74 particles from iord file.
# Halo ID 24167 has 96 particles from iord file.
# Halo ID 408 has 9238 particles from iord file.
# Halo ID 31227 has 68 particles from iord file.
# Halo ID 594 has 5895 particles from iord file.
# Halo ID 23569 has 99 particles from iord file.
# Halo ID 24632 has 94 particles from iord file.
# Halo ID 11972 has 228 particles from iord file.
# Halo ID 7218 has 403 particles from iord file.
# Halo ID 6773 has 432 particles from iord file.
# Halo ID 32042 has 66 particles from iord file.
# Halo ID 24734 has 93 particles from iord file.
# Halo ID 13805 has 192 particles from iord file.
# Halo ID 18593 has 134 particles from iord file.
# Halo ID 3158 has 974 particles from iord file.
# Halo ID 31660 has 67 particles from iord file.
# Halo ID 22807 has 103 particles from iord file.
# Halo ID 24395 has 95 particles from iord file.
# Halo ID 2610 has 1176 particles from iord file.
# Halo ID 3639 has 833 particles from iord file.
# Halo ID 6832 has 428 particles from iord file.
# Halo ID 417 has 8359 particles from iord file.
# Halo ID 24970 has 92 particles from iord file.
# Halo ID 10571 has 264 particles from iord file.
# Halo ID 32594 has 64 particles from iord file.
# Halo ID 11915 has 229 particles from iord file.
# Halo ID 26861 has 84 particles from iord file.
# Halo ID 8252 has 347 particles from iord file.
# Halo ID 30425 has 71 particles from iord file.
# Halo ID 1868 has 1688 particles from iord file.
# Halo ID 14079 has 187 particles from iord file.
# Halo ID 15468 has 166 particles from iord file.
# Halo ID 12178 has 223 particles from iord file.
# Halo ID 7330 has 395 particles from iord file.
# Halo ID 13933 has 190 particles from iord file.
# Halo ID 25231 has 91 particles from iord file.
# Halo ID 25987 has 88 particles from iord file.
# Halo ID 24124 has 96 particles from iord file.
# Halo ID 4764 has 632 particles from iord file.
# Halo ID 12323 has 220 particles from iord file.
# Halo ID 20572 has 118 particles from iord file.
# Halo ID 31243 has 68 particles from iord file.
# Halo ID 12567 has 215 particles from iord file.
# Halo ID 19174 has 128 particles from iord file.
# Halo ID 15165 has 170 particles from iord file.
# Halo ID 5809 has 511 particles from iord file.
# Halo ID 25839 has 88 particles from iord file.
# Halo ID 31235 has 68 particles from iord file.
# Halo ID 32390 has 65 particles from iord file.
# Halo ID 17419 has 144 particles from iord file.
# Halo ID 3806 has 794 particles from iord file.
# Halo ID 7206 has 404 particles from iord file.
# Halo ID 30012 has 72 particles from iord file.
# Halo ID 31267 has 68 particles from iord file.
# Halo ID 1882 has 1676 particles from iord file.
# Halo ID 5144 has 585 particles from iord file.
# Halo ID 32673 has 64 particles from iord file.
# Halo ID 8744 has 326 particles from iord file.
# Halo ID 17090 has 148 particles from iord file.
# Halo ID 8059 has 357 particles from iord file.
# Halo ID 517 has 6298 particles from iord file.
# Halo ID 3960 has 727 particles from iord file.
# Halo ID 21324 has 112 particles from iord file.
# Halo ID 22945 has 103 particles from iord file.
# Halo ID 8321 has 344 particles from iord file.
# Halo ID 17321 has 145 particles from iord file.
# Halo ID 2892 has 1000 particles from iord file.
# Halo ID 32829 has 64 particles from iord file.
# Halo ID 22588 has 104 particles from iord file.
# Halo ID 11797 has 231 particles from iord file.
# Halo ID 4435 has 677 particles from iord file.
# Halo ID 32352 has 65 particles from iord file.
# Halo ID 15015 has 172 particles from iord file.
# Halo ID 5993 has 495 particles from iord file.
# Halo ID 10791 has 258 particles from iord file.
# Halo ID 13625 has 195 particles from iord file.
# Halo ID 8559 has 334 particles from iord file.
# Halo ID 26449 has 86 particles from iord file.
# Halo ID 14964 has 173 particles from iord file.
# Halo ID 4930 has 612 particles from iord file.
# Halo ID 25589 has 89 particles from iord file.
# Halo ID 30629 has 70 particles from iord file.
# Halo ID 5957 has 498 particles from iord file.
# Halo ID 22281 has 106 particles from iord file.
# Halo ID 13301 has 201 particles from iord file.
# Halo ID 13462 has 198 particles from iord file.
# Halo ID 31213 has 68 particles from iord file.
# Halo ID 6871 has 426 particles from iord file.
# Halo ID 4796 has 628 particles from iord file.
# Halo ID 25511 has 90 particles from iord file.
# Halo ID 25024 has 92 particles from iord file.
# Halo ID 16631 has 153 particles from iord file.
# Halo ID 28139 has 79 particles from iord file.
# Halo ID 31800 has 67 particles from iord file.
# Halo ID 11913 has 229 particles from iord file.
# Halo ID 9240 has 307 particles from iord file.
# Halo ID 3387 has 901 particles from iord file.
# Halo ID 18492 has 135 particles from iord file.
# Halo ID 31353 has 68 particles from iord file.
# Halo ID 28098 has 79 particles from iord file.
# Halo ID 30283 has 71 particles from iord file.
# Halo ID 24263 has 96 particles from iord file.
# Halo ID 26552 has 85 particles from iord file.
# Halo ID 20631 has 117 particles from iord file.
# Halo ID 7494 has 386 particles from iord file.
# Halo ID 964 has 3443 particles from iord file.
# Halo ID 11565 has 237 particles from iord file.
# Halo ID 2363 has 1304 particles from iord file.
# Halo ID 18648 has 133 particles from iord file.
# Halo ID 2030 has 1540 particles from iord file.
# Halo ID 5508 has 544 particles from iord file.
# Halo ID 11663 has 234 particles from iord file.
# Halo ID 997 has 3340 particles from iord file.
# Halo ID 433 has 7895 particles from iord file.
# Halo ID 20057 has 122 particles from iord file.
# Halo ID 26077 has 87 particles from iord file.
# Halo ID 9628 has 293 particles from iord file.
# Halo ID 32098 has 66 particles from iord file.
# Halo ID 2980 has 1030 particles from iord file.
# Halo ID 16384 has 155 particles from iord file.
# Halo ID 10006 has 282 particles from iord file.
# Halo ID 26773 has 84 particles from iord file.
# Halo ID 17760 has 141 particles from iord file.
# Halo ID 32312 has 65 particles from iord file.
# Halo ID 5620 has 532 particles from iord file.
# Halo ID 9994 has 282 particles from iord file.
# Halo ID 10970 has 253 particles from iord file.
# Halo ID 4655 has 644 particles from iord file.
# Halo ID 29376 has 74 particles from iord file.
# Halo ID 8372 has 342 particles from iord file.
# Halo ID 11845 has 230 particles from iord file.
# Halo ID 17057 has 148 particles from iord file.
# Halo ID 5780 has 515 particles from iord file.
# Halo ID 31448 has 68 particles from iord file.
# Halo ID 18700 has 133 particles from iord file.
# Halo ID 18 has 529967 particles from iord file.
# Halo ID 32413 has 65 particles from iord file.
# Halo ID 524 has 6778 particles from iord file.
# Halo ID 19882 has 123 particles from iord file.
# Halo ID 31146 has 69 particles from iord file.
# Halo ID 29795 has 73 particles from iord file.
# Halo ID 13866 has 191 particles from iord file.
# Halo ID 20238 has 120 particles from iord file.
# Halo ID 1573 has 1931 particles from iord file.
# Halo ID 29095 has 75 particles from iord file.
# Halo ID 6348 has 465 particles from iord file.
# Halo ID 12980 has 207 particles from iord file.
# Halo ID 3527 has 864 particles from iord file.
# Halo ID 24386 has 95 particles from iord file.
# Halo ID 16330 has 156 particles from iord file.
# Halo ID 26384 has 86 particles from iord file.
# Halo ID 2900 has 1057 particles from iord file.
# Halo ID 30715 has 70 particles from iord file.
# Halo ID 19003 has 130 particles from iord file.
# Halo ID 6467 has 456 particles from iord file.
# Halo ID 19237 has 128 particles from iord file.
# Halo ID 16803 has 151 particles from iord file.
# Halo ID 929 has 3602 particles from iord file.
# Halo ID 3110 has 989 particles from iord file.
# Halo ID 11083 has 249 particles from iord file.
# Halo ID 23401 has 100 particles from iord file.
# Halo ID 20702 has 117 particles from iord file.
# Halo ID 27214 has 83 particles from iord file.
# Halo ID 22172 has 107 particles from iord file.
# Halo ID 25030 has 92 particles from iord file.
# Halo ID 13673 has 194 particles from iord file.
# Halo ID 11823 has 231 particles from iord file.
# Halo ID 30122 has 72 particles from iord file.
# Halo ID 13573 has 196 particles from iord file.
# Halo ID 29640 has 73 particles from iord file.
# Halo ID 8078 has 356 particles from iord file.
# Halo ID 5108 has 589 particles from iord file.
# Halo ID 18142 has 138 particles from iord file.
# Halo ID 8728 has 327 particles from iord file.
# Halo ID 25376 has 90 particles from iord file.
# Halo ID 11702 has 233 particles from iord file.
# Halo ID 27444 has 82 particles from iord file.
# Halo ID 19495 has 126 particles from iord file.
# Halo ID 5441 has 551 particles from iord file.
# Halo ID 4047 has 742 particles from iord file.
# Halo ID 20846 has 116 particles from iord file.
# Halo ID 30215 has 72 particles from iord file.
# Halo ID 9825 has 288 particles from iord file.
# Halo ID 10576 has 264 particles from iord file.
# Halo ID 19064 has 129 particles from iord file.
# Halo ID 22937 has 103 particles from iord file.
# Halo ID 26414 has 86 particles from iord file.
# Halo ID 27835 has 80 particles from iord file.
# Halo ID 31806 has 67 particles from iord file.
# Halo ID 13881 has 191 particles from iord file.
# Halo ID 15273 has 169 particles from iord file.
# Halo ID 10332 has 271 particles from iord file.
# Halo ID 29863 has 73 particles from iord file.
# Halo ID 14409 has 182 particles from iord file.
# Halo ID 17559 has 143 particles from iord file.
# Halo ID 10827 has 257 particles from iord file.
# Halo ID 5687 has 526 particles from iord file.
# Halo ID 1549 has 2045 particles from iord file.
# Halo ID 16130 has 158 particles from iord file.
# Halo ID 15704 has 163 particles from iord file.
# Halo ID 15272 has 169 particles from iord file.
# Halo ID 657 has 4948 particles from iord file.
# Halo ID 14497 has 181 particles from iord file.
# Halo ID 25819 has 88 particles from iord file.
# Halo ID 8167 has 352 particles from iord file.
# Halo ID 11632 has 235 particles from iord file.
# Halo ID 592 has 6019 particles from iord file.
# Halo ID 15860 has 162 particles from iord file.
# Halo ID 13398 has 199 particles from iord file.
# Halo ID 7478 has 386 particles from iord file.
# Halo ID 25597 has 89 particles from iord file.
# Halo ID 16530 has 154 particles from iord file.
# Halo ID 5053 has 596 particles from iord file.
# Halo ID 20457 has 118 particles from iord file.
# Halo ID 8908 has 320 particles from iord file.
# Halo ID 12040 has 226 particles from iord file.
# Halo ID 5073 has 593 particles from iord file.
# Halo ID 20658 has 117 particles from iord file.
# Halo ID 18302 has 136 particles from iord file.
# Halo ID 15519 has 166 particles from iord file.
# Halo ID 28000 has 79 particles from iord file.
# Halo ID 18964 has 130 particles from iord file.
# Halo ID 16533 has 154 particles from iord file.
# Halo ID 20946 has 115 particles from iord file.
# Halo ID 31195 has 68 particles from iord file.
# Halo ID 20902 has 115 particles from iord file.
# Halo ID 21728 has 110 particles from iord file.
# Halo ID 11131 has 248 particles from iord file.
# Halo ID 15698 has 164 particles from iord file.
# Halo ID 31392 has 68 particles from iord file.
# Halo ID 15493 has 166 particles from iord file.
# Halo ID 7142 has 407 particles from iord file.
# Halo ID 24750 has 93 particles from iord file.
# Halo ID 16418 has 155 particles from iord file.
# Halo ID 26430 has 86 particles from iord file.
# Halo ID 31683 has 67 particles from iord file.
# Halo ID 17701 has 142 particles from iord file.
# Halo ID 27952 has 80 particles from iord file.
# Halo ID 11363 has 241 particles from iord file.
# Halo ID 6774 has 432 particles from iord file.
# Halo ID 5392 has 556 particles from iord file.
# Halo ID 22425 has 105 particles from iord file.
# Halo ID 23392 has 100 particles from iord file.
# Halo ID 2569 has 1195 particles from iord file.
# Halo ID 29299 has 75 particles from iord file.
# Halo ID 19717 has 124 particles from iord file.
# Halo ID 18330 has 136 particles from iord file.
# Halo ID 21739 has 110 particles from iord file.
# Halo ID 22027 has 108 particles from iord file.
# Halo ID 12317 has 220 particles from iord file.
# Halo ID 631 has 5563 particles from iord file.
# Halo ID 418 has 8698 particles from iord file.
# Halo ID 8958 has 318 particles from iord file.
# Halo ID 583 has 5876 particles from iord file.
# Halo ID 1413 has 2244 particles from iord file.
# Halo ID 913 has 3446 particles from iord file.
# Halo ID 10336 has 271 particles from iord file.
# Halo ID 13239 has 202 particles from iord file.
# Halo ID 805 has 4316 particles from iord file.
# Halo ID 25905 has 88 particles from iord file.
# Halo ID 20225 has 120 particles from iord file.
# Halo ID 11426 has 240 particles from iord file.
# Halo ID 3979 has 756 particles from iord file.
# Halo ID 9577 has 295 particles from iord file.
# Halo ID 28834 has 76 particles from iord file.
# Halo ID 18831 has 131 particles from iord file.
# Halo ID 3839 has 787 particles from iord file.
# Halo ID 26326 has 86 particles from iord file.
# Halo ID 18727 has 132 particles from iord file.
# Halo ID 12440 has 217 particles from iord file.
# Halo ID 21122 has 114 particles from iord file.
# Halo ID 25710 has 89 particles from iord file.
# Halo ID 17818 has 141 particles from iord file.
# Halo ID 17100 has 147 particles from iord file.
# Halo ID 15555 has 165 particles from iord file.
# Halo ID 30792 has 70 particles from iord file.
# Halo ID 11448 has 237 particles from iord file.
# Halo ID 5373 has 558 particles from iord file.
# Halo ID 31234 has 68 particles from iord file.
# Halo ID 13179 has 203 particles from iord file.
# Halo ID 22686 has 104 particles from iord file.
# Halo ID 3275 has 932 particles from iord file.
# Halo ID 9977 has 282 particles from iord file.
# Halo ID 8046 has 358 particles from iord file.
# Halo ID 14672 has 178 particles from iord file.
# Halo ID 6022 has 491 particles from iord file.
# Halo ID 2007 has 1553 particles from iord file.
# Halo ID 2227 has 1387 particles from iord file.
# Halo ID 16950 has 149 particles from iord file.
# Halo ID 6872 has 426 particles from iord file.
# Halo ID 2942 has 1043 particles from iord file.
# Halo ID 8418 has 340 particles from iord file.
# Halo ID 14663 has 178 particles from iord file.
# Halo ID 8298 has 345 particles from iord file.
# Halo ID 11888 has 229 particles from iord file.
# Halo ID 9103 has 312 particles from iord file.
# Halo ID 18172 has 137 particles from iord file.
# Halo ID 8913 has 320 particles from iord file.
# Halo ID 23720 has 98 particles from iord file.
# Halo ID 16499 has 154 particles from iord file.
# Halo ID 12501 has 216 particles from iord file.
# Halo ID 12952 has 208 particles from iord file.
# Halo ID 29585 has 74 particles from iord file.
# Halo ID 32315 has 65 particles from iord file.
# Halo ID 14249 has 185 particles from iord file.
# Halo ID 16536 has 154 particles from iord file.
# Halo ID 29539 has 74 particles from iord file.
# Halo ID 31152 has 69 particles from iord file.
# Halo ID 28423 has 78 particles from iord file.
# Halo ID 27361 has 82 particles from iord file.
# Halo ID 7088 has 411 particles from iord file.
# Halo ID 12789 has 211 particles from iord file.
# Halo ID 19255 has 128 particles from iord file.
# Halo ID 20552 has 118 particles from iord file.
# Halo ID 7128 has 408 particles from iord file.
# Halo ID 22124 has 107 particles from iord file.
# Halo ID 15464 has 166 particles from iord file.
# Halo ID 3163 has 972 particles from iord file.
# Halo ID 8212 has 349 particles from iord file.
# Halo ID 16705 has 152 particles from iord file.
# Halo ID 21623 has 110 particles from iord file.
# Halo ID 743 has 4643 particles from iord file.
# Halo ID 6530 has 451 particles from iord file.
# Halo ID 4125 has 728 particles from iord file.
# Halo ID 24261 has 96 particles from iord file.
# Halo ID 16492 has 154 particles from iord file.
# Halo ID 18750 has 132 particles from iord file.
# Halo ID 9981 has 282 particles from iord file.
# Halo ID 20588 has 118 particles from iord file.
# Halo ID 28281 has 78 particles from iord file.
# Halo ID 3482 has 877 particles from iord file.
# Halo ID 24625 has 94 particles from iord file.
# Halo ID 12000 has 227 particles from iord file.
# Halo ID 26134 has 87 particles from iord file.
# Halo ID 31108 has 69 particles from iord file.
# Halo ID 10142 has 277 particles from iord file.
# Halo ID 30260 has 71 particles from iord file.
# Halo ID 5707 has 523 particles from iord file.
# Halo ID 31652 has 67 particles from iord file.
# Halo ID 7450 has 388 particles from iord file.
# Halo ID 7326 has 395 particles from iord file.
# Halo ID 2433 has 1263 particles from iord file.
# Halo ID 1885 has 1672 particles from iord file.
# Halo ID 5082 has 592 particles from iord file.
# Halo ID 1680 has 1885 particles from iord file.
# Halo ID 1643 has 1926 particles from iord file.
# Halo ID 15094 has 171 particles from iord file.
# Halo ID 23397 has 100 particles from iord file.
# Halo ID 30226 has 72 particles from iord file.
# Halo ID 17358 has 145 particles from iord file.
# Halo ID 27703 has 81 particles from iord file.
# Halo ID 14906 has 174 particles from iord file.
# Halo ID 16254 has 157 particles from iord file.
# Halo ID 32070 has 66 particles from iord file.
# Halo ID 12983 has 207 particles from iord file.
# Halo ID 26269 has 86 particles from iord file.
# Halo ID 11850 has 230 particles from iord file.
# Halo ID 8697 has 328 particles from iord file.
# Halo ID 26214 has 87 particles from iord file.
# Halo ID 23284 has 101 particles from iord file.
# Halo ID 27474 has 82 particles from iord file.
# Halo ID 23519 has 99 particles from iord file.
# Halo ID 27390 has 82 particles from iord file.
# Halo ID 29213 has 75 particles from iord file.
# Halo ID 7150 has 407 particles from iord file.
# Halo ID 12432 has 217 particles from iord file.
# Halo ID 28397 has 78 particles from iord file.
# Halo ID 28204 has 79 particles from iord file.
# Halo ID 11357 has 242 particles from iord file.
# Halo ID 18114 has 138 particles from iord file.
# Halo ID 32585 has 64 particles from iord file.
# Halo ID 2192 has 1255 particles from iord file.
# Halo ID 5569 has 537 particles from iord file.
# Halo ID 11377 has 241 particles from iord file.
# Halo ID 32696 has 64 particles from iord file.
# Halo ID 25241 has 91 particles from iord file.
# Halo ID 1405 has 2098 particles from iord file.
# Halo ID 4887 has 618 particles from iord file.
# Halo ID 27960 has 80 particles from iord file.
# Halo ID 21672 has 110 particles from iord file.
# Halo ID 11914 has 229 particles from iord file.
# Halo ID 17705 has 142 particles from iord file.
# Halo ID 15467 has 166 particles from iord file.
# Halo ID 24440 has 95 particles from iord file.
# Halo ID 29662 has 73 particles from iord file.
# Halo ID 30507 has 70 particles from iord file.
# Halo ID 32004 has 66 particles from iord file.
# Halo ID 28079 has 79 particles from iord file.
# Halo ID 29522 has 74 particles from iord file.
# Halo ID 29039 has 76 particles from iord file.
# Halo ID 26391 has 86 particles from iord file.
# Halo ID 25770 has 89 particles from iord file.
# Halo ID 30341 has 71 particles from iord file.
# Halo ID 420 has 8585 particles from iord file.
# Halo ID 24153 has 96 particles from iord file.
# Halo ID 28593 has 77 particles from iord file.
# Halo ID 32435 has 65 particles from iord file.
# Halo ID 9264 has 306 particles from iord file.
# Halo ID 31692 has 67 particles from iord file.
# Halo ID 23933 has 97 particles from iord file.
# Halo ID 31679 has 67 particles from iord file.
# Halo ID 20375 has 119 particles from iord file.
# Halo ID 24369 has 95 particles from iord file.
# Halo ID 5360 has 559 particles from iord file.
# Halo ID 24691 has 94 particles from iord file.
# Halo ID 16805 has 151 particles from iord file.
# Halo ID 16938 has 149 particles from iord file.
# Halo ID 12108 has 225 particles from iord file.
# Halo ID 1008 has 3318 particles from iord file.
# Halo ID 11089 has 249 particles from iord file.
# Halo ID 10402 has 269 particles from iord file.
# Halo ID 16444 has 155 particles from iord file.
# Halo ID 25889 has 88 particles from iord file.
# Halo ID 25894 has 88 particles from iord file.
# Halo ID 6285 has 470 particles from iord file.
# Halo ID 27161 has 83 particles from iord file.
# Halo ID 26484 has 85 particles from iord file.
# Halo ID 22020 has 108 particles from iord file.
# Halo ID 1289 has 2422 particles from iord file.
# Halo ID 12017 has 226 particles from iord file.
# Halo ID 4012 has 703 particles from iord file.
# Halo ID 17124 has 147 particles from iord file.
# Halo ID 21711 has 110 particles from iord file.
# Halo ID 19271 has 127 particles from iord file.
# Halo ID 32276 has 65 particles from iord file.
# Halo ID 30766 has 70 particles from iord file.
# Halo ID 9146 has 311 particles from iord file.
# Halo ID 1712 has 1856 particles from iord file.
# Halo ID 32100 has 66 particles from iord file.
# Halo ID 15444 has 167 particles from iord file.
# Halo ID 15922 has 161 particles from iord file.
# Halo ID 18169 has 137 particles from iord file.
# Halo ID 11624 has 235 particles from iord file.
# Halo ID 6582 has 447 particles from iord file.
# Halo ID 15000 has 173 particles from iord file.
# Halo ID 8000 has 360 particles from iord file.
# Halo ID 18053 has 138 particles from iord file.
# Halo ID 8304 has 345 particles from iord file.
# Halo ID 20467 has 118 particles from iord file.
# Halo ID 22069 has 108 particles from iord file.
# Halo ID 16156 has 158 particles from iord file.
# Halo ID 17149 has 147 particles from iord file.
# Halo ID 3432 has 782 particles from iord file.
# Halo ID 20427 has 119 particles from iord file.
# Halo ID 26856 has 84 particles from iord file.
# Halo ID 22683 has 104 particles from iord file.
# Halo ID 28076 has 79 particles from iord file.
# Halo ID 12012 has 227 particles from iord file.
# Halo ID 28122 has 79 particles from iord file.
# Halo ID 25735 has 89 particles from iord file.
# Halo ID 13419 has 199 particles from iord file.
# Halo ID 26820 has 84 particles from iord file.
# Halo ID 31082 has 69 particles from iord file.
# Halo ID 4093 has 733 particles from iord file.
# Halo ID 1527 has 2081 particles from iord file.
# Halo ID 22767 has 103 particles from iord file.
# Halo ID 16269 has 157 particles from iord file.
# Halo ID 19725 has 124 particles from iord file.
# Halo ID 4324 has 694 particles from iord file.
# Halo ID 12306 has 220 particles from iord file.
# Halo ID 2098 has 1485 particles from iord file.
# Halo ID 13549 has 196 particles from iord file.
# Halo ID 26631 has 85 particles from iord file.
# Halo ID 29504 has 74 particles from iord file.
# Halo ID 21072 has 114 particles from iord file.
# Halo ID 15637 has 164 particles from iord file.
# Halo ID 21540 has 111 particles from iord file.
# Halo ID 5906 has 503 particles from iord file.
# Halo ID 32861 has 64 particles from iord file.
# Halo ID 22282 has 106 particles from iord file.
# Halo ID 30372 has 71 particles from iord file.
# Halo ID 30485 has 71 particles from iord file.
# Halo ID 13152 has 204 particles from iord file.
# Halo ID 21885 has 109 particles from iord file.
# Halo ID 21014 has 115 particles from iord file.
# Halo ID 31520 has 67 particles from iord file.
# Halo ID 3422 has 892 particles from iord file.
# Halo ID 29372 has 74 particles from iord file.
# Halo ID 16592 has 153 particles from iord file.
# Halo ID 15682 has 164 particles from iord file.
# Halo ID 32510 has 65 particles from iord file.
# Halo ID 17445 has 144 particles from iord file.
# Halo ID 8781 has 325 particles from iord file.
# Halo ID 12196 has 223 particles from iord file.
# Halo ID 24751 has 93 particles from iord file.
# Halo ID 31432 has 68 particles from iord file.
# Halo ID 27956 has 80 particles from iord file.
# Halo ID 31181 has 68 particles from iord file.
# Halo ID 5775 has 515 particles from iord file.
# Halo ID 24160 has 96 particles from iord file.
# Halo ID 10952 has 253 particles from iord file.
# Halo ID 11225 has 245 particles from iord file.
# Halo ID 11199 has 246 particles from iord file.
# Halo ID 26595 has 85 particles from iord file.
# Halo ID 8374 has 342 particles from iord file.
# Halo ID 23099 has 102 particles from iord file.
# Halo ID 32332 has 65 particles from iord file.
# Halo ID 28064 has 79 particles from iord file.
# Halo ID 10987 has 252 particles from iord file.
# Halo ID 19805 has 123 particles from iord file.
# Halo ID 5009 has 601 particles from iord file.
# Halo ID 8268 has 347 particles from iord file.
# Halo ID 25556 has 90 particles from iord file.
# Halo ID 6358 has 463 particles from iord file.
# Halo ID 23223 has 101 particles from iord file.
# Halo ID 30173 has 72 particles from iord file.
# Halo ID 5693 has 525 particles from iord file.
# Halo ID 23396 has 100 particles from iord file.
# Halo ID 26052 has 87 particles from iord file.
# Halo ID 7245 has 401 particles from iord file.
# Halo ID 14376 has 183 particles from iord file.
# Halo ID 29361 has 74 particles from iord file.
# Halo ID 28839 has 76 particles from iord file.
# Halo ID 19596 has 125 particles from iord file.
# Halo ID 24390 has 95 particles from iord file.
# Halo ID 23310 has 100 particles from iord file.
# Halo ID 9833 has 287 particles from iord file.
# Halo ID 14826 has 176 particles from iord file.
# Halo ID 2744 has 1117 particles from iord file.
# Halo ID 8241 has 348 particles from iord file.
# Halo ID 31862 has 66 particles from iord file.
# Halo ID 6777 has 432 particles from iord file.
# Halo ID 32885 has 64 particles from iord file.
# Halo ID 11757 has 232 particles from iord file.
# Halo ID 21379 has 112 particles from iord file.
# Halo ID 20180 has 120 particles from iord file.
# Halo ID 9484 has 298 particles from iord file.
# Halo ID 16181 has 158 particles from iord file.
# Halo ID 2774 has 1108 particles from iord file.
# Halo ID 548 has 6443 particles from iord file.
# Halo ID 30390 has 71 particles from iord file.
# Halo ID 1381 has 2313 particles from iord file.
# Halo ID 18644 has 133 particles from iord file.
# Halo ID 2888 has 1063 particles from iord file.
# Halo ID 31702 has 67 particles from iord file.
# Halo ID 6998 has 417 particles from iord file.
# Halo ID 5041 has 597 particles from iord file.
# Halo ID 27682 has 81 particles from iord file.
# Halo ID 13384 has 199 particles from iord file.
# Halo ID 4466 has 672 particles from iord file.
# Halo ID 29371 has 74 particles from iord file.
# Halo ID 18206 has 137 particles from iord file.
# Halo ID 7629 has 379 particles from iord file.
# Halo ID 12184 has 223 particles from iord file.
# Halo ID 13057 has 206 particles from iord file.
# Halo ID 13283 has 201 particles from iord file.
# Halo ID 12530 has 216 particles from iord file.
# Halo ID 26073 has 87 particles from iord file.
# Halo ID 31802 has 67 particles from iord file.
# Halo ID 18190 has 137 particles from iord file.
# Halo ID 23184 has 101 particles from iord file.
# Halo ID 873 has 3922 particles from iord file.
# Halo ID 16203 has 158 particles from iord file.
# Halo ID 24548 has 94 particles from iord file.
# Halo ID 8324 has 344 particles from iord file.
# Halo ID 24812 has 93 particles from iord file.
# Halo ID 18938 has 130 particles from iord file.
# Halo ID 8782 has 325 particles from iord file.
# Halo ID 11600 has 236 particles from iord file.
# Halo ID 24567 has 94 particles from iord file.
# Halo ID 4495 has 669 particles from iord file.
# Halo ID 2950 has 1041 particles from iord file.
# Halo ID 12776 has 211 particles from iord file.
# Halo ID 17927 has 140 particles from iord file.
# Halo ID 4834 has 623 particles from iord file.
# Halo ID 9118 has 312 particles from iord file.
# Halo ID 7646 has 378 particles from iord file.
# Halo ID 30598 has 70 particles from iord file.
# Halo ID 31363 has 68 particles from iord file.
# Halo ID 25906 has 88 particles from iord file.
# Halo ID 19289 has 127 particles from iord file.
# Halo ID 21757 has 109 particles from iord file.
# Halo ID 27641 has 81 particles from iord file.
# Halo ID 22728 has 104 particles from iord file.
# Halo ID 6171 has 479 particles from iord file.
# Halo ID 19828 has 123 particles from iord file.
# Halo ID 22794 has 103 particles from iord file.
# Halo ID 8807 has 324 particles from iord file.
# Halo ID 31343 has 68 particles from iord file.
# Halo ID 25859 has 88 particles from iord file.
# Halo ID 32152 has 66 particles from iord file.
# Halo ID 13037 has 206 particles from iord file.
# Halo ID 27181 has 83 particles from iord file.
# Halo ID 29536 has 74 particles from iord file.
# Halo ID 13948 has 190 particles from iord file.
# Halo ID 29919 has 73 particles from iord file.
# Halo ID 9913 has 285 particles from iord file.
# Halo ID 31969 has 66 particles from iord file.
# Halo ID 21432 has 112 particles from iord file.
# Halo ID 28115 has 79 particles from iord file.
# Halo ID 42 has 187333 particles from iord file.
# Halo ID 20972 has 115 particles from iord file.
# Halo ID 5038 has 598 particles from iord file.
# Halo ID 13220 has 202 particles from iord file.
# Halo ID 40 has 178122 particles from iord file.
# Halo ID 13580 has 196 particles from iord file.
# Halo ID 7809 has 369 particles from iord file.
# Halo ID 20466 has 118 particles from iord file.
# Halo ID 22556 has 105 particles from iord file.
# Halo ID 12489 has 216 particles from iord file.
# Halo ID 12721 has 212 particles from iord file.
# Halo ID 8244 has 348 particles from iord file.
# Halo ID 16333 has 156 particles from iord file.
# Halo ID 18846 has 131 particles from iord file.
# Halo ID 12047 has 226 particles from iord file.
# Halo ID 18760 has 132 particles from iord file.
# Halo ID 28794 has 77 particles from iord file.
# Halo ID 31189 has 68 particles from iord file.
# Halo ID 70 has 86448 particles from iord file.
# Halo ID 10289 has 273 particles from iord file.
# Halo ID 11186 has 246 particles from iord file.
# Halo ID 24616 has 94 particles from iord file.
# Halo ID 78 has 83709 particles from iord file.
# Halo ID 31577 has 67 particles from iord file.
# Halo ID 20929 has 115 particles from iord file.
# Halo ID 23475 has 100 particles from iord file.
# Halo ID 3165 has 972 particles from iord file.
# Halo ID 17783 has 141 particles from iord file.
# Halo ID 10884 has 255 particles from iord file.
# Halo ID 23740 has 98 particles from iord file.
# Halo ID 4550 has 660 particles from iord file.
# Halo ID 22931 has 103 particles from iord file.
# Halo ID 17042 has 148 particles from iord file.
# Halo ID 7360 has 393 particles from iord file.
# Halo ID 24180 has 96 particles from iord file.
# Halo ID 25367 has 90 particles from iord file.
# Halo ID 1762 has 1807 particles from iord file.
# Halo ID 15758 has 163 particles from iord file.
# Halo ID 5394 has 556 particles from iord file.
# Halo ID 18560 has 134 particles from iord file.
# Halo ID 10413 has 269 particles from iord file.
# Halo ID 24156 has 96 particles from iord file.
# Halo ID 1103 has 2956 particles from iord file.
# Halo ID 7395 has 392 particles from iord file.
# Halo ID 1755 has 1815 particles from iord file.
# Halo ID 15126 has 171 particles from iord file.
# Halo ID 1032 has 3212 particles from iord file.
# Halo ID 3003 has 1022 particles from iord file.
# Halo ID 2686 has 916 particles from iord file.
# Halo ID 22265 has 106 particles from iord file.
# Halo ID 5966 has 498 particles from iord file.
# Halo ID 16944 has 149 particles from iord file.
# Halo ID 18068 has 138 particles from iord file.
# Halo ID 22905 has 103 particles from iord file.
# Halo ID 22087 has 107 particles from iord file.
# Halo ID 25643 has 89 particles from iord file.
# Halo ID 12894 has 209 particles from iord file.
# Halo ID 31238 has 68 particles from iord file.
# Halo ID 21804 has 109 particles from iord file.
# Halo ID 12137 has 224 particles from iord file.
# Halo ID 3069 has 1002 particles from iord file.
# Halo ID 8654 has 330 particles from iord file.
# Halo ID 5855 has 507 particles from iord file.
# Halo ID 28045 has 79 particles from iord file.
# Halo ID 2978 has 1031 particles from iord file.
# Halo ID 2844 has 1081 particles from iord file.
# Halo ID 20594 has 118 particles from iord file.
# Halo ID 19372 has 127 particles from iord file.
# Halo ID 21488 has 111 particles from iord file.
# Halo ID 13322 has 200 particles from iord file.
# Halo ID 11933 has 228 particles from iord file.
# Halo ID 26476 has 86 particles from iord file.
# Halo ID 27966 has 80 particles from iord file.
# Halo ID 7649 has 378 particles from iord file.
# Halo ID 5094 has 590 particles from iord file.
# Halo ID 24636 has 94 particles from iord file.
# Halo ID 8737 has 326 particles from iord file.
# Halo ID 24471 has 95 particles from iord file.
# Halo ID 18741 has 132 particles from iord file.
# Halo ID 16720 has 152 particles from iord file.
# Halo ID 26323 has 86 particles from iord file.
# Halo ID 22445 has 105 particles from iord file.
# Halo ID 5294 has 568 particles from iord file.
# Halo ID 15226 has 169 particles from iord file.
# Halo ID 15964 has 160 particles from iord file.
# Halo ID 25333 has 91 particles from iord file.
# Halo ID 25581 has 89 particles from iord file.
# Halo ID 26365 has 86 particles from iord file.
# Halo ID 18747 has 132 particles from iord file.
# Halo ID 22308 has 106 particles from iord file.
# Halo ID 12070 has 225 particles from iord file.
# Halo ID 11787 has 231 particles from iord file.
# Halo ID 32927 has 64 particles from iord file.
# Halo ID 31827 has 67 particles from iord file.
# Halo ID 225 has 20002 particles from iord file.
# Halo ID 23972 has 97 particles from iord file.
# Halo ID 16209 has 158 particles from iord file.
# Halo ID 22496 has 105 particles from iord file.
# Halo ID 27456 has 82 particles from iord file.
# Halo ID 19918 has 123 particles from iord file.
# Halo ID 13943 has 190 particles from iord file.
# Halo ID 5826 has 509 particles from iord file.
# Halo ID 27043 has 83 particles from iord file.
# Halo ID 22778 has 103 particles from iord file.
# Halo ID 29223 has 75 particles from iord file.
# Halo ID 32652 has 64 particles from iord file.
# Halo ID 21729 has 110 particles from iord file.
# Halo ID 6396 has 460 particles from iord file.
# Halo ID 13765 has 192 particles from iord file.
# Halo ID 4540 has 661 particles from iord file.
# Halo ID 14742 has 177 particles from iord file.
# Halo ID 2 has 6154067 particles from iord file.
# Halo ID 18839 has 131 particles from iord file.
# Halo ID 13030 has 206 particles from iord file.
# Halo ID 5267 has 539 particles from iord file.
# Halo ID 11561 has 237 particles from iord file.
# Halo ID 15928 has 161 particles from iord file.
# Halo ID 21725 has 110 particles from iord file.
# Halo ID 13337 has 200 particles from iord file.
# Halo ID 5898 has 503 particles from iord file.
# Halo ID 32338 has 65 particles from iord file.
# Halo ID 18094 has 138 particles from iord file.
# Halo ID 30371 has 71 particles from iord file.
# Halo ID 1769 has 1801 particles from iord file.
# Halo ID 11113 has 248 particles from iord file.
# Halo ID 8102 has 355 particles from iord file.
# Halo ID 469 has 7499 particles from iord file.
# Halo ID 24525 has 94 particles from iord file.
# Halo ID 19009 has 130 particles from iord file.
# Halo ID 244 has 17865 particles from iord file.
# Halo ID 9098 has 313 particles from iord file.
# Halo ID 9792 has 289 particles from iord file.
# Halo ID 17621 has 142 particles from iord file.
# Halo ID 2201 has 1412 particles from iord file.
# Halo ID 9761 has 290 particles from iord file.
# Halo ID 5859 has 507 particles from iord file.
# Halo ID 8464 has 338 particles from iord file.
# Halo ID 32335 has 65 particles from iord file.
# Halo ID 15103 has 171 particles from iord file.
# Halo ID 20610 has 117 particles from iord file.
# Halo ID 24561 has 94 particles from iord file.
# Halo ID 4688 has 640 particles from iord file.
# Halo ID 17757 has 141 particles from iord file.
# Halo ID 11948 has 228 particles from iord file.
# Halo ID 29493 has 74 particles from iord file.
# Halo ID 13619 has 195 particles from iord file.
# Halo ID 30237 has 71 particles from iord file.
# Halo ID 2415 has 1272 particles from iord file.
# Halo ID 3285 has 929 particles from iord file.
# Halo ID 19232 has 128 particles from iord file.
# Halo ID 21831 has 109 particles from iord file.
# Halo ID 10165 has 276 particles from iord file.
# Halo ID 26493 has 85 particles from iord file.
# Halo ID 1863 has 1694 particles from iord file.
# Halo ID 7873 has 366 particles from iord file.
# Halo ID 347 has 10993 particles from iord file.
# Halo ID 2019 has 1544 particles from iord file.
# Halo ID 32937 has 64 particles from iord file.
# Halo ID 13381 has 199 particles from iord file.
# Halo ID 11686 has 234 particles from iord file.
# Halo ID 6079 has 486 particles from iord file.
# Halo ID 25105 has 92 particles from iord file.
# Halo ID 452 has 7698 particles from iord file.
# Halo ID 21018 has 114 particles from iord file.
# Halo ID 22180 has 107 particles from iord file.
# Halo ID 29148 has 75 particles from iord file.
# Halo ID 7001 has 417 particles from iord file.
# Halo ID 32889 has 64 particles from iord file.
# Halo ID 30340 has 71 particles from iord file.
# Halo ID 23228 has 101 particles from iord file.
# Halo ID 25870 has 88 particles from iord file.
# Halo ID 30099 has 72 particles from iord file.
# Halo ID 14547 has 180 particles from iord file.
# Halo ID 30898 has 69 particles from iord file.
# Halo ID 31466 has 68 particles from iord file.
# Halo ID 21425 has 112 particles from iord file.
# Halo ID 3663 has 828 particles from iord file.
# Halo ID 407 has 9140 particles from iord file.
# Halo ID 1079 has 3016 particles from iord file.
# Halo ID 3218 has 955 particles from iord file.
# Halo ID 11807 has 231 particles from iord file.
# Halo ID 1921 has 1631 particles from iord file.
# Halo ID 31643 has 67 particles from iord file.
# Halo ID 272 has 15687 particles from iord file.
# Halo ID 9679 has 292 particles from iord file.
# Halo ID 310 has 12992 particles from iord file.
# Halo ID 10864 has 256 particles from iord file.
# Halo ID 15254 has 169 particles from iord file.
# Halo ID 18336 has 136 particles from iord file.
# Halo ID 28067 has 79 particles from iord file.
# Halo ID 2324 has 1324 particles from iord file.
# Halo ID 13487 has 197 particles from iord file.
# Halo ID 24433 has 95 particles from iord file.
# Halo ID 23570 has 99 particles from iord file.
# Halo ID 6928 has 422 particles from iord file.
# Halo ID 32281 has 65 particles from iord file.
# Halo ID 16699 has 152 particles from iord file.
# Halo ID 10082 has 279 particles from iord file.
# Halo ID 1987 has 1571 particles from iord file.
# Halo ID 30416 has 71 particles from iord file.
# Halo ID 29911 has 73 particles from iord file.
# Halo ID 8570 has 333 particles from iord file.
# Halo ID 13520 has 197 particles from iord file.
# Halo ID 29719 has 73 particles from iord file.
# Halo ID 26367 has 86 particles from iord file.
# Halo ID 31729 has 67 particles from iord file.
# Halo ID 11999 has 227 particles from iord file.
# Halo ID 9361 has 303 particles from iord file.
# Halo ID 8770 has 325 particles from iord file.
# Halo ID 1052 has 3119 particles from iord file.
# Halo ID 4147 has 723 particles from iord file.
# Halo ID 8296 has 345 particles from iord file.
# Halo ID 7916 has 363 particles from iord file.
# Halo ID 16978 has 149 particles from iord file.
# Halo ID 31116 has 69 particles from iord file.
# Halo ID 21708 has 110 particles from iord file.
# Halo ID 6027 has 491 particles from iord file.
# Halo ID 11867 has 230 particles from iord file.
# Halo ID 26467 has 86 particles from iord file.
# Halo ID 1693 has 1871 particles from iord file.
# Halo ID 6028 has 491 particles from iord file.
# Halo ID 25529 has 90 particles from iord file.
# Halo ID 10688 has 261 particles from iord file.
# Halo ID 12657 has 213 particles from iord file.
# Halo ID 2969 has 1034 particles from iord file.
# Halo ID 9165 has 310 particles from iord file.
# Halo ID 9173 has 310 particles from iord file.
# Halo ID 27704 has 81 particles from iord file.
# Halo ID 4029 has 745 particles from iord file.
# Halo ID 15267 has 169 particles from iord file.
# Halo ID 3814 has 793 particles from iord file.
# Halo ID 4627 has 649 particles from iord file.
# Halo ID 31020 has 69 particles from iord file.
# Halo ID 1479 has 2152 particles from iord file.
# Halo ID 31706 has 67 particles from iord file.
# Halo ID 6018 has 492 particles from iord file.
# Halo ID 9563 has 295 particles from iord file.
# ...
# Halo ID 27358 has 82 particles from iord file.
# Halo ID 32014 has 66 particles from iord file.
# Halo ID 2023 has 1542 particles from iord file.
# Halo ID 30892 has 69 particles from iord file.
# Halo ID 3818 has 792 particles from iord file.
# Halo ID 3587 has 846 particles from iord file.
# Halo ID 20350 has 119 particles from iord file.
# Halo ID 2682 has 1147 particles from iord file.
# Halo ID 17478 has 144 particles from iord file.
# Halo ID 18575 has 134 particles from iord file.
# Halo ID 26167 has 87 particles from iord file.
# Halo ID 18354 has 136 particles from iord file.
# Halo ID 14267 has 184 particles from iord file.
# Halo ID 17077 has 148 particles from iord file.
# Halo ID 10693 has 260 particles from iord file.
# Halo ID 10526 has 265 particles from iord file.
# Halo ID 10524 has 265 particles from iord file.
# Halo ID 20301 has 120 particles from iord file.
# Halo ID 31701 has 67 particles from iord file.
# Halo ID 20623 has 117 particles from iord file.
# Halo ID 26608 has 85 particles from iord file.
# Halo ID 30443 has 71 particles from iord file.
# Halo ID 31669 has 67 particles from iord file.
# Halo ID 7522 has 385 particles from iord file.
# Halo ID 26570 has 85 particles from iord file.
# Halo ID 9047 has 314 particles from iord file.
# Halo ID 26480 has 85 particles from iord file.
# Halo ID 4645 has 646 particles from iord file.
# Halo ID 15293 has 168 particles from iord file.
# Halo ID 24976 has 92 particles from iord file.
# Halo ID 10353 has 271 particles from iord file.
# Halo ID 20606 has 117 particles from iord file.
# Halo ID 21099 has 114 particles from iord file.
# Halo ID 25293 has 91 particles from iord file.
# Halo ID 24934 has 93 particles from iord file.
# Halo ID 10465 has 267 particles from iord file.
# Halo ID 23890 has 97 particles from iord file.
# Halo ID 21220 has 113 particles from iord file.
# Halo ID 27172 has 83 particles from iord file.
# Halo ID 18021 has 139 particles from iord file.
# Halo ID 20023 has 122 particles from iord file.
# Halo ID 31977 has 66 particles from iord file.
# Halo ID 3385 has 901 particles from iord file.
# Halo ID 2638 has 1165 particles from iord file.
# Halo ID 16770 has 151 particles from iord file.
# Halo ID 28989 has 76 particles from iord file.
# Halo ID 11233 has 245 particles from iord file.
# Halo ID 30217 has 72 particles from iord file.
# Halo ID 7805 has 369 particles from iord file.
# Halo ID 16096 has 159 particles from iord file.
# Halo ID 13588 has 196 particles from iord file.
# Halo ID 17859 has 140 particles from iord file.
# Halo ID 9888 has 285 particles from iord file.
# Halo ID 22575 has 105 particles from iord file.
# Halo ID 22166 has 107 particles from iord file.
# Halo ID 14196 has 185 particles from iord file.
# Halo ID 23209 has 101 particles from iord file.
# Halo ID 24808 has 93 particles from iord file.
# Halo ID 15234 has 169 particles from iord file.
# Halo ID 15753 has 163 particles from iord file.
# Halo ID 10379 has 270 particles from iord file.
# Halo ID 28054 has 79 particles from iord file.
# Halo ID 21838 has 109 particles from iord file.
# Halo ID 17933 has 140 particles from iord file.
# Halo ID 18867 has 131 particles from iord file.
# Halo ID 7542 has 384 particles from iord file.
# Halo ID 25982 has 88 particles from iord file.
# Halo ID 19297 has 127 particles from iord file.
# Halo ID 7029 has 415 particles from iord file.
# Halo ID 15065 has 172 particles from iord file.
# Halo ID 31948 has 66 particles from iord file.
# Halo ID 23853 has 98 particles from iord file.
# Halo ID 31261 has 68 particles from iord file.
# Halo ID 16924 has 149 particles from iord file.
# Halo ID 16642 has 153 particles from iord file.
# Halo ID 24023 has 97 particles from iord file.
# Halo ID 32227 has 65 particles from iord file.
# Halo ID 15571 has 165 particles from iord file.
# Halo ID 15815 has 162 particles from iord file.
# Halo ID 19740 has 124 particles from iord file.
# Halo ID 30111 has 72 particles from iord file.
# Halo ID 20062 has 121 particles from iord file.
# Halo ID 11837 has 230 particles from iord file.
# Halo ID 32266 has 65 particles from iord file.
# Halo ID 12664 has 213 particles from iord file.
# Halo ID 13601 has 195 particles from iord file.
# Halo ID 11570 has 237 particles from iord file.
# Halo ID 18809 has 132 particles from iord file.
# Halo ID 29243 has 75 particles from iord file.
# Halo ID 31078 has 69 particles from iord file.
# Halo ID 21164 has 114 particles from iord file.
# Halo ID 22700 has 104 particles from iord file.
# Halo ID 14944 has 174 particles from iord file.
# Halo ID 27769 has 80 particles from iord file.
# Halo ID 20819 has 116 particles from iord file.
# Halo ID 9963 has 283 particles from iord file.
# Halo ID 19099 has 129 particles from iord file.
# Halo ID 24025 has 97 particles from iord file.
# Halo ID 32917 has 64 particles from iord file.
# Halo ID 19203 has 128 particles from iord file.
# Halo ID 5010 has 442 particles from iord file.
# Halo ID 8044 has 358 particles from iord file.
# Halo ID 5757 has 518 particles from iord file.
# Halo ID 25739 has 89 particles from iord file.
# Halo ID 32355 has 65 particles from iord file.
# Halo ID 7331 has 395 particles from iord file.
# Halo ID 17408 has 144 particles from iord file.
# Halo ID 24807 has 93 particles from iord file.
# Halo ID 21250 has 113 particles from iord file.
# Halo ID 6664 has 441 particles from iord file.
# Halo ID 27461 has 82 particles from iord file.
# Halo ID 15310 has 168 particles from iord file.
# Halo ID 27584 has 81 particles from iord file.
# Halo ID 29501 has 74 particles from iord file.
# Halo ID 21467 has 112 particles from iord file.
# Halo ID 19212 has 128 particles from iord file.
# Halo ID 27749 has 80 particles from iord file.
# Halo ID 21033 has 114 particles from iord file.
# Halo ID 21979 has 108 particles from iord file.
# Halo ID 27264 has 82 particles from iord file.
# Halo ID 13879 has 191 particles from iord file.
# Halo ID 12784 has 211 particles from iord file.
# Halo ID 12621 has 214 particles from iord file.
# Halo ID 20791 has 116 particles from iord file.
# Halo ID 21017 has 114 particles from iord file.
# Halo ID 30995 has 69 particles from iord file.
# Halo ID 17181 has 147 particles from iord file.
# Halo ID 18194 has 137 particles from iord file.
# Halo ID 31658 has 67 particles from iord file.
# Halo ID 31038 has 69 particles from iord file.
# Halo ID 12714 has 212 particles from iord file.
# Halo ID 15124 has 171 particles from iord file.
# Halo ID 28078 has 79 particles from iord file.
# Halo ID 25067 has 92 particles from iord file.
# Halo ID 10882 has 255 particles from iord file.
# Halo ID 6241 has 473 particles from iord file.
# Halo ID 16660 has 152 particles from iord file.
# Halo ID 29851 has 73 particles from iord file.
# Halo ID 30616 has 70 particles from iord file.
# Halo ID 20860 has 116 particles from iord file.
# Halo ID 22707 has 104 particles from iord file.
# Halo ID 5912 has 502 particles from iord file.
# Halo ID 24980 has 92 particles from iord file.
# Halo ID 10630 has 262 particles from iord file.
# Halo ID 20414 has 119 particles from iord file.
# Halo ID 15770 has 163 particles from iord file.
# Halo ID 11195 has 225 particles from iord file.
# Halo ID 28192 has 79 particles from iord file.
# Halo ID 7774 has 370 particles from iord file.
# Halo ID 16358 has 156 particles from iord file.
# Halo ID 16627 has 153 particles from iord file.
# Halo ID 8741 has 326 particles from iord file.
# Halo ID 18362 has 136 particles from iord file.
# Halo ID 8725 has 327 particles from iord file.
# Halo ID 28300 has 78 particles from iord file.
# Halo ID 14621 has 179 particles from iord file.
# Halo ID 22076 has 107 particles from iord file.
# Halo ID 17188 has 146 particles from iord file.
# Halo ID 31777 has 67 particles from iord file.
# Halo ID 8092 has 355 particles from iord file.
# Halo ID 25196 has 91 particles from iord file.
# Halo ID 6708 has 438 particles from iord file.
# Halo ID 27761 has 80 particles from iord file.
# Halo ID 28320 has 78 particles from iord file.
# Halo ID 17891 has 140 particles from iord file.
# Halo ID 17702 has 142 particles from iord file.
# Halo ID 28725 has 77 particles from iord file.
# Halo ID 15488 has 166 particles from iord file.
# Halo ID 31321 has 68 particles from iord file.
# Halo ID 13174 has 203 particles from iord file.
# Halo ID 22639 has 104 particles from iord file.
# Halo ID 32736 has 64 particles from iord file.
# Halo ID 22474 has 105 particles from iord file.
# Halo ID 18155 has 138 particles from iord file.
# Halo ID 13168 has 203 particles from iord file.
# Halo ID 24719 has 93 particles from iord file.
# Halo ID 9406 has 301 particles from iord file.
# Halo ID 23002 has 102 particles from iord file.
# Halo ID 11832 has 230 particles from iord file.
# Halo ID 13159 has 204 particles from iord file.
# Halo ID 9162 has 310 particles from iord file.
# Halo ID 8387 has 342 particles from iord file.
# Halo ID 28763 has 77 particles from iord file.
# Halo ID 13786 has 192 particles from iord file.
# Halo ID 11975 has 227 particles from iord file.
# Halo ID 2736 has 1120 particles from iord file.
# Halo ID 25306 has 91 particles from iord file.
# Halo ID 1136 has 2859 particles from iord file.
# Halo ID 31539 has 67 particles from iord file.
# Halo ID 15128 has 171 particles from iord file.
# Halo ID 2117 has 1471 particles from iord file.
# Halo ID 5669 has 528 particles from iord file.
# Halo ID 22995 has 102 particles from iord file.
# Halo ID 12423 has 217 particles from iord file.
# Halo ID 22174 has 107 particles from iord file.
# Halo ID 21810 has 109 particles from iord file.
# Halo ID 27202 has 83 particles from iord file.
# Halo ID 10951 has 253 particles from iord file.
# Halo ID 27790 has 80 particles from iord file.
# Halo ID 31714 has 67 particles from iord file.
# Halo ID 30916 has 69 particles from iord file.
# Halo ID 26348 has 86 particles from iord file.
# Halo ID 32705 has 64 particles from iord file.
# Halo ID 26503 has 85 particles from iord file.
# Halo ID 19278 has 127 particles from iord file.
# Halo ID 2586 has 1070 particles from iord file.
# Halo ID 4068 has 737 particles from iord file.
# Halo ID 8554 has 334 particles from iord file.
# Halo ID 10577 has 264 particles from iord file.
# Halo ID 12931 has 208 particles from iord file.
# Halo ID 26174 has 87 particles from iord file.
# Halo ID 29770 has 73 particles from iord file.
# Halo ID 13681 has 194 particles from iord file.
# Halo ID 1983 has 1574 particles from iord file.
# Halo ID 9525 has 297 particles from iord file.
# Halo ID 24313 has 95 particles from iord file.
# Halo ID 25937 has 88 particles from iord file.
# Halo ID 17990 has 139 particles from iord file.
# Halo ID 753 has 4661 particles from iord file.
# Halo ID 21938 has 108 particles from iord file.
# Halo ID 21140 has 114 particles from iord file.
# Halo ID 16208 has 158 particles from iord file.
# Halo ID 5956 has 498 particles from iord file.
# Halo ID 10954 has 253 particles from iord file.
# Halo ID 676 has 4957 particles from iord file.
# Halo ID 10458 has 267 particles from iord file.
# Halo ID 5601 has 534 particles from iord file.
# Halo ID 22115 has 107 particles from iord file.
# Halo ID 11066 has 250 particles from iord file.
# Halo ID 11941 has 228 particles from iord file.
# Halo ID 32499 has 65 particles from iord file.
# Halo ID 15932 has 161 particles from iord file.
# Halo ID 28624 has 77 particles from iord file.
# Halo ID 22219 has 107 particles from iord file.
# Halo ID 12925 has 208 particles from iord file.
# Halo ID 9763 has 290 particles from iord file.
# Halo ID 23774 has 98 particles from iord file.
# Halo ID 22315 has 106 particles from iord file.
# Halo ID 15523 has 166 particles from iord file.
# Halo ID 14785 has 176 particles from iord file.
# Halo ID 7710 has 374 particles from iord file.
# Halo ID 4536 has 662 particles from iord file.
# Halo ID 6044 has 490 particles from iord file.
# Halo ID 23316 has 100 particles from iord file.
# Halo ID 2522 has 1218 particles from iord file.
# Halo ID 11254 has 245 particles from iord file.
# Halo ID 29249 has 75 particles from iord file.
# Halo ID 18926 has 131 particles from iord file.
# Halo ID 14823 has 176 particles from iord file.
# Halo ID 16268 has 157 particles from iord file.
# Halo ID 22652 has 104 particles from iord file.
# Halo ID 25017 has 92 particles from iord file.
# Halo ID 28951 has 76 particles from iord file.
# Halo ID 12781 has 211 particles from iord file.
# Halo ID 28870 has 76 particles from iord file.
# Halo ID 21956 has 108 particles from iord file.
# Halo ID 9301 has 305 particles from iord file.
# Halo ID 24283 has 96 particles from iord file.
# Halo ID 23304 has 100 particles from iord file.
# Halo ID 4889 has 618 particles from iord file.
# Halo ID 8550 has 334 particles from iord file.
# Halo ID 23672 has 99 particles from iord file.
# Halo ID 21557 has 111 particles from iord file.
# Halo ID 7613 has 380 particles from iord file.
# Halo ID 10962 has 253 particles from iord file.
# Halo ID 30513 has 70 particles from iord file.
# Halo ID 11014 has 251 particles from iord file.
# Halo ID 20403 has 119 particles from iord file.
# Halo ID 15675 has 164 particles from iord file.
# Halo ID 21929 has 108 particles from iord file.
# Halo ID 19418 has 126 particles from iord file.
# Halo ID 19441 has 126 particles from iord file.
# Halo ID 10046 has 280 particles from iord file.
# Halo ID 14702 has 177 particles from iord file.
# Halo ID 8969 has 318 particles from iord file.
# Halo ID 18318 has 136 particles from iord file.
# Halo ID 28987 has 76 particles from iord file.
# Halo ID 22638 has 104 particles from iord file.
# Halo ID 3735 has 811 particles from iord file.
# Halo ID 22339 has 106 particles from iord file.
# Halo ID 17081 has 148 particles from iord file.
# Halo ID 30280 has 71 particles from iord file.
# Halo ID 6536 has 451 particles from iord file.
# Halo ID 26982 has 83 particles from iord file.
# Halo ID 19839 has 123 particles from iord file.
# Halo ID 26354 has 86 particles from iord file.
# Halo ID 9650 has 293 particles from iord file.
# Halo ID 8478 has 337 particles from iord file.
# Halo ID 4326 has 694 particles from iord file.
# Halo ID 24256 has 96 particles from iord file.
# Halo ID 5370 has 558 particles from iord file.
# Halo ID 29733 has 73 particles from iord file.
# Halo ID 25778 has 89 particles from iord file.
# Halo ID 14956 has 174 particles from iord file.
# Halo ID 6971 has 419 particles from iord file.
# Halo ID 25329 has 91 particles from iord file.
# Halo ID 12102 has 225 particles from iord file.
# Halo ID 30433 has 71 particles from iord file.
# Halo ID 22077 has 107 particles from iord file.
# Halo ID 6632 has 444 particles from iord file.
# Halo ID 27174 has 83 particles from iord file.
# Halo ID 28921 has 76 particles from iord file.
# Halo ID 8126 has 354 particles from iord file.
# Halo ID 11890 has 229 particles from iord file.
# Halo ID 31764 has 67 particles from iord file.
# Halo ID 29341 has 74 particles from iord file.
# Halo ID 28864 has 76 particles from iord file.
# Halo ID 17591 has 143 particles from iord file.
# Halo ID 9724 has 291 particles from iord file.
# Halo ID 16947 has 149 particles from iord file.
# Halo ID 8460 has 338 particles from iord file.
# Halo ID 15730 has 163 particles from iord file.
# Halo ID 26217 has 87 particles from iord file.
# Halo ID 30660 has 70 particles from iord file.
# Halo ID 17779 has 141 particles from iord file.
# Halo ID 23795 has 98 particles from iord file.
# Halo ID 9720 has 291 particles from iord file.
# Halo ID 8528 has 335 particles from iord file.
# Halo ID 24216 has 96 particles from iord file.
# Halo ID 7477 has 387 particles from iord file.
# Halo ID 6345 has 466 particles from iord file.
# Halo ID 10180 has 276 particles from iord file.
# Halo ID 16493 has 154 particles from iord file.
# Halo ID 25547 has 90 particles from iord file.
# Halo ID 28187 has 79 particles from iord file.
# Halo ID 18584 has 134 particles from iord file.
# Halo ID 8142 has 353 particles from iord file.
# Halo ID 32775 has 64 particles from iord file.
# Halo ID 26652 has 85 particles from iord file.
# Halo ID 17602 has 142 particles from iord file.
# Halo ID 24368 has 95 particles from iord file.
# Halo ID 20679 has 117 particles from iord file.
# Halo ID 21435 has 112 particles from iord file.
# Halo ID 22024 has 108 particles from iord file.
# Halo ID 11907 has 229 particles from iord file.
# Halo ID 30014 has 72 particles from iord file.

# %%
# Validate file paths before loading AHF catalogues
if validate_file_path(ahf_basename_s1):
    h_1 = pynbody.halo.ahf.AHFCatalogue(s_1, filename=ahf_basename_s1)
else:
    print("Skipping loading for simulation 1 due to missing file.")

if validate_file_path(ahf_basename_s2):
    h_2 = pynbody.halo.ahf.AHFCatalogue(s_2, filename=ahf_basename_s2)
else:
    print("Skipping loading for simulation 2 due to missing file.")

# %%
h_1 = h_2

# %%
print(h_1[1].dm.loadable_keys())
print(h_2[1].dm.loadable_keys())

# %%
min_overlap_percentage = .5
halo_match_counter = {}


min_overlap_percentage = 50  # Minimum overlap percentage to consider halos matched
halo_match_counter = {}

# Iterate over halos in the first simulation
for i in range(1, 7):  # Adjust range if needed
    iord_1 = h_1[i].dm['iord']
    num_particles_1 = len(iord_1)  # Total particles in halo i from sim 1
    print('n1', num_particles_1)

    # Iterate over halos in the second simulation
    for j in range(1, 7):  # Adjust range if needed
        iord_2 = h_2[j].dm['iord']
        common_particles = np.intersect1d(iord_1, iord_2)
        total_common = len(common_particles)
        
        num_particles_2 = len(iord_2)  # Total particles in halo j from sim 2
        
        # Calculate overlap as a percentage of each halo's particle count
        overlap_1 = (total_common / num_particles_1) * 100
        overlap_2 = (total_common / num_particles_2) * 100

        # Check if overlap meets the minimum threshold against the larger halo
        if max(overlap_1, overlap_2) >= min_overlap_percentage:
            # Preventing subhalo-host matches by ensuring the match is significant for the larger halo
            if max(num_particles_1, num_particles_2) == num_particles_2 and overlap_1 >= min_overlap_percentage:
                if (i, j) not in halo_match_counter:
                    halo_match_counter[(i, j)] = overlap_1
            elif max(num_particles_1, num_particles_2) == num_particles_1 and overlap_2 >= min_overlap_percentage:
                if (i, j) not in halo_match_counter:
                    halo_match_counter[(i, j)] = overlap_2


# Print the best matches that meet the criteria
for match, overlap in sorted(halo_match_counter.items(), key=lambda x: x[1], reverse=True):
    print(f'Halo {match[0]} in Simulation 1 matches Halo {match[1]} in Simulation 2 with {overlap:.2f}% overlap of particle IDs.')

# %%
import pandas as pd

# Assuming halo_match_counter contains the match data
# Convert dictionary to DataFrame for easier handling
matches_df = pd.DataFrame(list(halo_match_counter.items()), columns=['Match', 'Overlap'])
matches_df[['Halo1', 'Halo2']] = pd.DataFrame(matches_df['Match'].tolist(), index=matches_df.index)
matches_df.drop(columns=['Match'], inplace=True)

# Save to CSV file
matches_df.to_csv('halo_matches.csv', index=False)
